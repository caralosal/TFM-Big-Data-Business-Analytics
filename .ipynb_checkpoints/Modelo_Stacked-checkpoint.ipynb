# %%
import pandas as pd
import matplotlib.pyplot as plt
from metricas import *
import numpy as np

def read_predictions(file, col):
    df = pd.read_csv(file, index_col = 0)
    df.index = pd.to_datetime(df.index)
    df = df[["Pred"]]
    df.columns = [col]
    return df

persistencia = pd.read_csv('Resultados/resultados_baseline.csv', index_col = 0)
persistencia.index = pd.to_datetime(persistencia.index)
persistencia = persistencia[["Real", "Pred"]]

rf = read_predictions('Resultados/resultados_rf.csv', 'RF')
xgboost = read_predictions('Resultados/resultados_xgboost.csv', 'XGBoost')
reg_lin = read_predictions('Resultados/resultados_regresion_lineal.csv', 'Reg_Lin')
lasso = read_predictions('Resultados/resultados_reg_lasso.csv', 'Lasso')
ridge = read_predictions('Resultados/resultados_reg_ridge.csv', 'Ridge')

# %%
stacked = persistencia.reset_index().merge(rf.reset_index(), left_on = 'Fecha', right_on = 'index', how = 'outer')\
                          .merge(xgboost.reset_index(), how = 'outer')\
                          .merge(reg_lin.reset_index(), how = 'outer')\
                          .merge(lasso.reset_index(), how = 'outer')\
                          .merge(ridge.reset_index(), how = 'outer')

stacked = stacked.drop(columns = 'index')
stacked = stacked.set_index('Fecha')

# %% [markdown]
# ### Regresión Lineal

# %%
import statsmodels.api as sm

df_stacked = stacked[["Pred", "Reg_Lin", "Lasso", "Ridge", "Real"]].dropna(subset = ["Pred", "Reg_Lin", "Lasso", "Ridge", "Real"])
df_stacked
# Out:
#                        Pred     Reg_Lin       Lasso       Ridge    Real
# Fecha
# 2021-01-01 00:00:00   42.11   36.882201   34.014742   36.870040   50.87
# 2021-01-01 01:00:00   37.03   33.129181   30.600821   33.115572   48.19
# 2021-01-01 02:00:00   35.25   29.655874   27.575039   29.644849   44.68
# 2021-01-01 03:00:00   31.82   26.055521   24.205573   26.061262   38.50
# 2021-01-01 04:00:00   31.67   23.825573   21.806992   23.835446   36.80
# ...                     ...         ...         ...         ...     ...
# 2021-12-31 19:00:00  251.79  221.605358  220.887963  221.665996  187.95
# 2021-12-31 20:00:00  248.63  214.586653  217.616447  214.643738  182.30
# 2021-12-31 21:00:00  240.00  202.905005  209.344834  202.963844  175.12
# 2021-12-31 22:00:00  202.40  185.801803  191.700463  185.860590  140.38
# 2021-12-31 23:00:00  185.90  178.227844  183.413697  178.280654  127.81
#
# [8760 rows x 5 columns]
